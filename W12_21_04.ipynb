# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mtcnn in /usr/local/lib/python3.9/dist-packages (0.1.1)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from mtcnn) (4.7.0.72)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from mtcnn) (2.12.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.9/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.22.4)

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename='/content/doibong.jpg'
img=plt.imread(filename)
plt.imshow(img)
detector= MTCNN()
faces=detector.detect_faces(img)
for face in faces:
  print(faces)
# Out:
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 10/10 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 22ms/step
# [{'box': [165, 156, 33, 41], 'confidence': 0.99998539686203, 'keypoints': {'left_eye': (175, 172), 'right_eye': (190, 172), 'nose': (183, 182), 'mouth_left': (176, 188), 'mouth_right': (187, 189)}}, {'box': [490, 193, 30, 37], 'confidence': 0.9999054074287415, 'keypoints': {'left_eye': (498, 205), 'right_eye': (513, 205), 'nose': (506, 211), 'mouth_left': (500, 220), 'mouth_right': (511, 220)}}, {'box': [714, 177, 32, 42], 'confidence': 0.9998304843902588, 'keypoints': {'left_eye': (721, 193), 'right_eye': (736, 192), 'nose': (729, 200), 'mouth_left': (723, 209), 'mouth_right': (736, 208)}}, {'box': [643, 276, 34, 40], 'confidence': 0.9997507333755493, 'keypoints': {'left_eye': (652, 291), 'right_eye': (668, 291), 'nose': (660, 301), 'mouth_left': (654, 307), 'mouth_right': (667, 307)}}, {'box': [781, 267, 32, 40], 'confidence': 0.9995383620262146, 'keypoints': {'left_eye': (789, 282), 'right_eye': (804, 281), 'nose': (796, 291), 'mouth_left': (791, 298), 'mouth_right': (803, 297)}}, {'box': [368, 166, 30, 40], 'confidence': 0.9994546175003052, 'keypoints': {'left_eye': (376, 182), 'right_eye': (390, 182), 'nose': (383, 189), 'mouth_left': (377, 197), 'mouth_right': (388, 197)}}, {'box': [605, 177, 31, 40], 'confidence': 0.9993457198143005, 'keypoints': {'left_eye': (613, 193), 'right_eye': (627, 193), 'nose': (620, 201), 'mouth_left': (614, 208), 'mouth_right': (626, 208)}}, {'box': [276, 236, 32, 42], 'confidence': 0.9993360638618469, 'keypoints': {'left_eye': (284, 250), 'right_eye': (299, 252), 'nose': (291, 260), 'mouth_left': (284, 267), 'mouth_right': (297, 269)}}, {'box': [269, 174, 29, 41], 'confidence': 0.999045193195343, 'keypoints': {'left_eye': (277, 190), 'right_eye': (291, 192), 'nose': (283, 197), 'mouth_left': (277, 205), 'mouth_right': (288, 206)}}, {'box': [381, 251, 32, 42], 'confidence': 0.9989908337593079, 'keypoints': {'left_eye': (389, 266), 'right_eye': (404, 267), 'nose': (396, 276), 'mouth_left': (390, 283), 'mouth_right': (402, 284)}}, {'box': [518, 275, 33, 44], 'confidence': 0.9986981153488159, 'keypoints': {'left_eye': (527, 291), 'right_eye': (543, 292), 'nose': (535, 301), 'mouth_left': (529, 309), 'mouth_right': (541, 309)}}, {'box': [215, 0, 34, 30], 'confidence': 0.7568944096565247, 'keypoints': {'left_eye': (225, 4), 'right_eye': (242, 3), 'nose': (234, 17), 'mouth_left': (228, 23), 'mouth_right': (240, 23)}}]
 'keypoints': {'left_eye': (652, 291), 'right_eye': (668, 291), 'nose': (660, 301), 'mouth_left': (654, 307), 'mouth_right': (667, 307)}}, {'box': [781, 267, 32, 40], 'confidence': 0.9995383620262146, 'keypoints': {'left_eye': (789, 282), 'right_eye': (804, 281), 'nose': (796, 291), 'mouth_left': (791, 298), 'mouth_right': (803, 297)}}, {'box': [368, 166, 30, 40], 'confidence': 0.9994546175003052, 'keypoints': {'left_eye': (376, 182), 'right_eye': (390, 182), 'nose': (383, 189), 'mouth_left': (377, 197), 'mouth_right': (388, 197)}}, {'box': [605, 177, 31, 40], 'confidence': 0.9993457198143005, 'keypoints': {'left_eye': (613, 193), 'right_eye': (627, 193), 'nose': (620, 201), 'mouth_left': (614, 208), 'mouth_right': (626, 208)}}, {'box': [276, 236, 32, 42], 'confidence': 0.9993360638618469, 'keypoints': {'left_eye': (284, 250), 'right_eye': (299, 252), 'nose': (291, 260), 'mouth_left': (284, 267), 'mouth_right': (297, 269)}}, {'box': [269, 174, 29, 41], 'confidence': 0.999045193195343, 'keypoints': {'left_eye': (277, 190), 'right_eye': (291, 192), 'nose': (283, 197), 'mouth_left': (277, 205), 'mouth_right': (288, 206)}}, {'box': [381, 251, 32, 42], 'confidence': 0.9989908337593079, 'keypoints': {'left_eye': (389, 266), 'right_eye': (404, 267), 'nose': (396, 276), 'mouth_left': (390, 283), 'mouth_right': (402, 284)}}, {'box': [518, 275, 33, 44], 'confidence': 0.9986981153488159, 'keypoints': {'left_eye': (527, 291), 'right_eye': (543, 292), 'nose': (535, 301), 'mouth_left': (529, 309), 'mouth_right': (541, 309)}}, {'box': [215, 0, 34, 30], 'confidence': 0.7568944096565247, 'keypoints': {'left_eye': (225, 4), 'right_eye': (242, 3), 'nose': (234, 17), 'mouth_left': (228, 23), 'mouth_right': (240, 23)}}]
# [{'box': [165, 156, 33, 41], 'confidence': 0.99998539686203, 'keypoints': {'left_eye': (175, 172), 'right_eye': (190, 172), 'nose': (183, 182), 'mouth_left': (176, 188), 'mouth_right': (187, 189)}}, {'box': [490, 193, 30, 37], 'confidence': 0.9999054074287415, 'keypoints': {'left_eye': (498, 205), 'right_eye': (513, 205), 'nose': (506, 211), 'mouth_left': (500, 220), 'mouth_right': (511, 220)}}, {'box': [714, 177, 32, 42], 'confidence': 0.9998304843902588, 'keypoints': {'left_eye': (721, 193), 'right_eye': (736, 192), 'nose': (729, 200), 'mouth_left': (723, 209), 'mouth_right': (736, 208)}}, {'box': [643, 276, 34, 40], 'confidence': 0.9997507333755493, 'keypoints': {'left_eye': (652, 291), 'right_eye': (668, 291), 'nose': (660, 301), 'mouth_left': (654, 307), 'mouth_right': (667, 307)}}, {'box': [781, 267, 32, 40], 'confidence': 0.9995383620262146, 'keypoints': {'left_eye': (789, 282), 'right_eye': (804, 281), 'nose': (796, 291), 'mouth_left': (791, 298), 'mouth_right': (803, 297)}}, {'box': [368, 166, 30, 40], 'confidence': 0.9994546175003052, 'keypoints': {'left_eye': (376, 182), 'right_eye': (390, 182), 'nose': (383, 189), 'mouth_left': (377, 197), 'mouth_right': (388, 197)}}, {'box': [605, 177, 31, 40], 'confidence': 0.9993457198143005, 'keypoints': {'left_eye': (613, 193), 'right_eye': (627, 193), 'nose': (620, 201), 'mouth_left': (614, 208), 'mouth_right': (626, 208)}}, {'box': [276, 236, 32, 42], 'confidence': 0.9993360638618469, 'keypoints': {'left_eye': (284, 250), 'right_eye': (299, 252), 'nose': (291, 260), 'mouth_left': (284, 267), 'mouth_right': (297, 269)}}, {'box': [269, 174, 29, 41], 'confidence': 0.999045193195343, 'keypoints': {'left_eye': (277, 190), 'right_eye': (291, 192), 'nose': (283, 197), 'mouth_left': (277, 205), 'mouth_right': (288, 206)}}, {'box': [381, 251, 32, 42], 'confidence': 0.9989908337593079, 'keypoints': {'left_eye': (389, 266), 'right_eye': (404, 267), 'nose': (396, 276), 'mouth_left': (390, 283), 'mouth_right': (402, 284)}}, {'box': [518, 275, 33, 44], 'confidence': 0.9986981153488159, 'keypoints': {'left_eye': (527, 291), 'right_eye': (543, 292), 'nose': (535, 301), 'mouth_left': (529, 309), 'mouth_right': (541, 309)}}, {'box': [215, 0, 34, 30], 'confidence': 0.7568944096565247, 'keypoints': {'left_eye': (225, 4), 'right_eye': (242, 3), 'nose': (234, 17), 'mouth_left': (228, 23), 'mouth_right': (240, 23)}}]

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

filename = '/content/doibong.jpg'
img = plt.imread(filename)

detector = MTCNN()
faces = detector.detect_faces(img)

ax = plt.gca()

for face in faces:
    x, y, width, height = face['box']
    rect = plt.Rectangle((x,y), width, height, fill=False, color='red')
    ax.add_patch(rect)
    
    for key, value in face['keypoints'].items():
        dot = plt.Circle(value, radius=2, color='red')
        ax.add_patch(dot)

plt.imshow(img)
# Out:
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 10/10 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 34ms/step

# %%
import matplotlib.pyplot as plt

def draw_faces(filename, result_list):
  data=plt.imread(filename)
  for i in range(len(result_list)):
    x1, y1, width, height=result_list[i]['box']
    x2, y2=x1+width, y1+height
    plt.subplot(1, len(result_list), i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
plt.show()

filename = '/content/doibong.jpg'
detector = MTCNN()
faces = detector.detect_faces(plt.imread(filename))
draw_faces(filename, faces)
# Out:
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 10/10 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 34ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename='/content/.jpg'
img=plt.imread(filename)
plt.imshow(img)
detector= MTCNN()
faces=detector.detect_faces(img)
for face in faces:
  print(faces)

import matplotlib.pyplot as plt
from mtcnn import MTCNN

ax = plt.gca()
for face in faces:
    x, y, width, height = face['box']
    rect = plt.Rectangle((x,y), width, height, fill=False, color='red')
    ax.add_patch(rect)
    for key, value in face['keypoints'].items():
        dot = plt.Circle(value, radius=2, color='red')
        ax.add_patch(dot)
plt.imshow(img)
filename = '/content/doibong.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
ax = plt.gca()
for face in faces:
    x, y, width, height = face['box']
    rect = plt.Rectangle((x,y), width, height, fill=False, color='red')
    ax.add_patch(rect)
    for key, value in face['keypoints'].items():
        dot = plt.Circle(value, radius=2, color='red')
        ax.add_patch(dot)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
import matplotlib.pyplot as plt
from mtcnn import MTCNN
tf.keras.applications.ResNet50(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    **kwargs
)
#ResNet, VGG,

# %%
pip install tensorflow

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = 'cho5.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n02110063', 'malamute', 0.39872196), ('n02109961', 'Eskimo_dog', 0.31346527), ('n02110185', 'Siberian_husky', 0.23676407)]

# %%
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top=True)

img_path = 'cho2.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 754ms/step
# Predicted: [('n02106662', 'German_shepherd', 0.92497575), ('n02105162', 'malinois', 0.06254639), ('n02111129', 'Leonberg', 0.0048318435)]

# %%
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top=True)

img_path = 'pencil.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 690ms/step
# Predicted: [('n04116512', 'rubber_eraser', 0.7603614), ('n03908714', 'pencil_sharpener', 0.15156725), ('n03876231', 'paintbrush', 0.022322446)]

# %%
model = VGG16(weights='imagenet', include_top=True)
img_path = 'BanPhim.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 712ms/step
# Predicted: [('n03085013', 'computer_keyboard', 0.65828055), ('n04264628', 'space_bar', 0.2935182), ('n04505470', 'typewriter_keyboard', 0.027841484)]

# %%
model = VGG16(weights='imagenet', include_top=True)
img_path = 'download.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n02974003', 'car_wheel', 0.48184514), ('n03843555', 'oil_filter', 0.4240476), ('n03208938', 'disk_brake', 0.02589906)]

# %%
from tensorflow.keras.applications.vgg19 import VGG19, decode_predictions
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.models import Model
import numpy as np

base_model = VGG19(weights='imagenet')
model = Model(inputs=base_model.input, outputs=base_model.get_layer('block4_pool').output)

img_path = 'cho2.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

block4_pool_features = model.predict(x)
print('Predicted:', decode_predictions(block4_pool_features, top=3)[0])

# %%
#Ve chuan bi am thanh chuyen qua duoi wav, bo phan intro di, Làm lời bài hát. Nhiều ngôn ngữ. Đem theo tai nghe. Thu âm thanh của một số loài động vật
#Dịch, viết, phân tích nhận dạng tiếng. Xử lý âm thanh.
